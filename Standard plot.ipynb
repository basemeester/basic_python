# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=5, micro=2, releaselevel='final', serial=0)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/rik/.anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/rik/.anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
fig = plt.figure(figsize = (5.0, 5.0) )

data = range(10)

axis0 = fig.add_subplot(2, 2, 1)
axis0.set_ylabel('y-as')
axis0.plot(data)


fig.tight_layout()

plt.show

fig.savefig('books_read.png')

# %%
I = plt.imread('scan.tif')

# %%
fig_scan = plt.imshow(I, origin='lower')
plt.ylabel('y')

# %%
I.shape
# Out:
# (300, 300, 4)

# %%
I2=I[100:201, :50, :]

# %%
fig_crop = plt.figure()
crop = plt.imshow(I2, origin='lower')

# %%
fig_crop.savefig('crop.tif')

# %%
np.mean(I[100:201,:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6362cbf53c13> in <module>()
# ----> 1 np.mean(I[100:201,:])
#
# NameError: name 'np' is not defined
